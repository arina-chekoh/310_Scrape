# %%
# import module
import requests
from bs4 import BeautifulSoup
import pandas as pd

page = 1
HEADERS = ({'User-Agent':
            'Mozilla/5.0 (Windows NT 10.0; Win64; x64) \
            AppleWebKit/537.36 (KHTML, like Gecko) \
            Chrome/90.0.4430.212 Safari/537.36',
            'Accept-Language': 'en-US, en;q=0.5'})
def getdata(url):
    r = requests.get(url, headers=HEADERS)
    return r.text

def html_code(url):

    # pass the url
    # into getdata function
    htmldata = getdata(url)
    soup = BeautifulSoup(htmldata, 'html.parser')
    return soup
    
def product_info(soup):
    # find the Html tag
    # with find()
    # and convert into string
    data_str = ""
    pro_info = []
  
    for item in soup.find_all("h1", class_="a-size-large a-text-ellipsis"):
        data_str = data_str + item.get_text()
        pro_info.append(data_str)
        data_str = ""
    return pro_info 

def cus_data(soup):
# find the Html tag
# with find()
# and convert into string
    data_str = ""
    cus_list = []

    for item in soup.find_all("a", class_="a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold"):
        data_str = data_str + item.get_text()
        data_str = data_str.replace('\n','')
        cus_list.append(data_str)
        data_str = ""
    return cus_list

def cus_rev(soup):
    # find the Html tag
    # with find()
    # and convert into string
    data_str = ""

    for item in soup.find_all("span", class_="a-size-base review-text review-text-content"):
        data_str = data_str + item.get_text()

    result = data_str.split("\n")
    return (result)

Product = []
Review = []    
Detail = []   
    
while page <= 25:
    
    url = 'https://www.amazon.com/Blue-Buffalo-Protection-Formula-Adult/product-reviews/B0009YWKUA/ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=' + str(page)
    #url = requests.get('https://www.amazon.com/HillS-Science-Diet-Chicken-Recipe/product-reviews/B003CL3PTM/ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=' + str(page))
    #print(url)
    
    
    soup = html_code(url)
    pro_result = product_info(soup)
    Product = pro_result
    
    cus_res = cus_data(soup)
    for x in cus_res:
        Review.append(x)
    rev_data = cus_rev(soup)
    rev_result = []
    for i in rev_data:
        if i == "":
            pass
        else:
            rev_result.append(i)
    for y in rev_result:
        Detail.append(y)
    
    print('complete page number: ',page)
    page += 1
print(Product)   
# Create DataFrame
table = pd.DataFrame([Review, Detail]).transpose()
table.columns = ['Review', 'Detail']
# Save the output.
table.set_index('Review')
# Out:
# complete page number:  1
# complete page number:  2
# complete page number:  3
# complete page number:  4
# complete page number:  5
# complete page number:  6
# complete page number:  7
# complete page number:  8
# complete page number:  9
# complete page number:  10
# complete page number:  11
# complete page number:  12
# complete page number:  13
# complete page number:  14
# complete page number:  15
# complete page number:  16
# complete page number:  17
# complete page number:  18
# complete page number:  19
# complete page number:  20
# complete page number:  21
# complete page number:  22
# complete page number:  23
# complete page number:  24
# complete page number:  25
# ['Blue Buffalo Life Protection Formula Natural Adult Dry Dog Food, Chicken and Brown Rice 30-lb']
#                                                                                          Detail
# Review
# My dogs love it - but currently out of stock  Yes and yes! Both my border collie and Chihuah...
# ...

# %%
table.to_csv('Comment_Blue Buffalo.csv',encoding='utf-8-sig')

# %%
# import module
import requests
from bs4 import BeautifulSoup
import pandas as pd

page = 1
HEADERS = ({'User-Agent':
            'Mozilla/5.0 (Windows NT 10.0; Win64; x64) \
            AppleWebKit/537.36 (KHTML, like Gecko) \
            Chrome/90.0.4430.212 Safari/537.36',
            'Accept-Language': 'en-US, en;q=0.5'})
def getdata(url):
    r = requests.get(url, headers=HEADERS)
    return r.text

def html_code(url):

    # pass the url
    # into getdata function
    htmldata = getdata(url)
    soup = BeautifulSoup(htmldata, 'html.parser')
    return soup
    
def product_info(soup):
    # find the Html tag
    # with find()
    # and convert into string
    data_str = ""
    pro_info = []
  
    for item in soup.find_all("h1", class_="a-size-large a-text-ellipsis"):
        data_str = data_str + item.get_text()
        pro_info.append(data_str)
        data_str = ""
    return pro_info 

def cus_data(soup):
# find the Html tag
# with find()
# and convert into string
    data_str = ""
    cus_list = []

    for item in soup.find_all("a", class_="a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold"):
        data_str = data_str + item.get_text()
        data_str = data_str.replace('\n','')
        cus_list.append(data_str)
        data_str = ""
    return cus_list

def cus_rev(soup):
    # find the Html tag
    # with find()
    # and convert into string
    data_str = ""

    for item in soup.find_all("span", class_="a-size-base review-text review-text-content"):
        data_str = data_str + item.get_text()

    result = data_str.split("\n")
    return (result)

Product = []
Review = []    
Detail = []   
    
while page <= 25:
    
    url = 'https://www.amazon.com/Purina-Pro-Plan-Shredded-Chicken/product-reviews/B001QCKS4O/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber=' + str(page)
    #url = requests.get('https://www.amazon.com/HillS-Science-Diet-Chicken-Recipe/product-reviews/B003CL3PTM/ref=cm_cr_getr_d_paging_btm_prev_1?ie=UTF8&reviewerType=all_reviews&pageNumber=' + str(page))
    #print(url)
    
    
    soup = html_code(url)
    pro_result = product_info(soup)
    Product = pro_result
    
    cus_res = cus_data(soup)
    for a in cus_res:
        Review.append(a)
    rev_data = cus_rev(soup)
    rev_result = []
    for i in rev_data:
        if i == "":
            pass
        else:
            rev_result.append(i)
    for b in rev_result:
        Detail.append(b)
    
    print('complete page number: ',page)
    page += 1
print(Product)   
# Create DataFrame
table = pd.DataFrame([Review, Detail]).transpose()
table.columns = ['Review', 'Detail']
# Save the output.
table.set_index('Review')
# Out:
# complete page number:  1
# complete page number:  2
# complete page number:  3
# complete page number:  4
# complete page number:  5
# complete page number:  6
# complete page number:  7
# complete page number:  8
# complete page number:  9
# complete page number:  10
# complete page number:  11
# complete page number:  12
# complete page number:  13
# complete page number:  14
# complete page number:  15
# complete page number:  16
# complete page number:  17
# complete page number:  18
# complete page number:  19
# complete page number:  20
# complete page number:  21
# complete page number:  22
# complete page number:  23
# complete page number:  24
# complete page number:  25
# ['Purina Pro Plan High Protein Dog Food With Probiotics for Dogs, Shredded Blend Chicken & Rice Formula - 35 lb. Bag']
#                                                                                                Detail
# Review
# ...

# %%
table.to_csv('Comment_Purina Pro.csv',encoding='utf-8-sig')
